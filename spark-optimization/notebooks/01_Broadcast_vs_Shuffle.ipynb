# %%
from pyspark.sql import functions as F
from data_generator import get_spark, generate_large_table, generate_small_lookup
import time
spark=get_spark('Case01_BroadcastJoin')

large_df=generate_large_table(spark,num_rows=20_000_00)
small_df=generate_small_lookup(spark,num_rows=5_000)

large_df.cache().count()
small_df.cache().count()
# Out:
# 26/04/10 17:11:53 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 5000

# %% [markdown]
# # BAD: Default SortMergeJoin (shuffle both)

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")

# %%
small_df_clean = small_df.drop("id")
start = time.time()
result_bad = large_df.join(small_df_clean, "category", "inner")
result_bad.write.mode("overwrite").parquet("/tmp/case01_bad")
print(f"SortMergeJoin: {time.time() - start:.1f}s")
# Out:
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 26/04/10 17:12:05 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 47.50% for 16 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:06 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# [Stage 12:=================================================>      (16 + 2) / 18]
# SortMergeJoin: 4.0s

# %% [markdown]
# # GOOD: Explicit Broadcast Join

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "50MB")

# %%
start = time.time()
result_good = large_df.join(F.broadcast(small_df_clean), "category", "inner")
result_good.write.mode("overwrite").parquet("/tmp/case01_good")
print(f" BroadcastJoin: {time.time() - start:.1f}s")
# Out:
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 26/04/10 17:12:23 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 47.50% for 16 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:24 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to
WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 17:12:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# [Stage 15:====================================================> (195 + 5) / 200]
#  BroadcastJoin: 3.5s

# %%
print("\n--- BAD PLAN ---")
result_bad.explain(True)
print("\n--- GOOD PLAN ---")
result_good.explain(True)
# Out:
# --- BAD PLAN ---
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [category])
# :- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % cast(50 as bigint)) as string)) AS category#27]
# :  +- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * cast(500000 as double)) as bigint) AS upload_bytes#20L]
# :     +- Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * cast(1000000 as double)) as bigint) AS download_bytes#14L]
# :        +- Project [id#0L, account_number#2, event_date#5, cast((rand(-1990789066734320550) * cast(3600 as double)) as int) AS session_duration#9]
# :           +- Project [id#0L, account_number#2, date_add(cast(2025-01-01 as date), cast((id#0L % cast(90 as bigint)) as int)) AS event_date#5]
# :              +- Project [id#0L, cast((id#0L % cast(500000 as bigint)) as string) AS account_number#2]
# :                 +- Range (0, 2000000, step=1, splits=Some(200))
# +- Project [category#37, category_name#40, priority#44]
#    +- Project [id#35L, category#37, category_name#40, cast((rand(-1294804350127073887) * cast(10 as double)) as int) AS priority#44]
#       +- Project [id#35L, category#37, concat(Category , cast(id#35L as string)) AS category_name#40]
#          +- Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37]
#             +- Range (0, 5000, step=1, splits=Some(16))
#
# == Analyzed Logical Plan ==
# category: string, id: bigint, account_number: string, event_date: date, session_duration: int, download_bytes: bigint, upload_bytes: bigint, category_name: string, priority: int
# Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
# +- Join Inner, (category#27 = category#37)
#    :- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % cast(50 as bigint)) as string)) AS category#27]
#    :  +- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * cast(500000 as double)) as bigint) AS upload_bytes#20L]
#    :     +- Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * cast(1000000 as double)) as bigint) AS download_bytes#14L]
#    :        +- Project [id#0L, account_number#2, event_date#5, cast((rand(-1990789066734320550) * cast(3600 as double)) as int) AS session_duration#9]
#    :           +- Project [id#0L, account_number#2, date_add(cast(2025-01-01 as date), cast((id#0L % cast(90 as bigint)) as int)) AS event_date#5]
#    :              +- Project [id#0L, cast((id#0L % cast(500000 as bigint)) as string) AS account_number#2]
#    :                 +- Range (0, 2000000, step=1, splits=Some(200))
#    +- Project [category#37, category_name#40, priority#44]
#       +- Project [id#35L, category#37, category_name#40, cast((rand(-1294804350127073887) * cast(10 as double)) as int) AS priority#44]
#          +- Project [id#35L, category#37, concat(Category , cast(id#35L as string)) AS category_name#40]
#             +- Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37]
#                +- Range (0, 5000, step=1, splits=Some(16))
#
# == Optimized Logical Plan ==
# Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
# +- Join Inner, (category#27 = category#37)
#    :- Filter isnotnull(category#27)
#    :  +- InMemoryRelation [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % 50) as string)) AS category#27]
#    :           +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * 500000.0) as bigint) AS upload_bytes#20L]
#    :              +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * 1000000.0) as bigint) AS download_bytes#14L]
#    :                 +- *(1) Project [id#0L, cast((id#0L % 500000) as string) AS account_number#2, date_add(2025-01-01, cast((id#0L % 90) as int)) AS event_date#5, cast((rand(-1990789066734320550) * 3600.0) as int) AS session_duration#9]
#    :                    +- *(1) Range (0, 2000000, step=1, splits=200)
#    +- Project [category#37, category_name#40, priority#44]
#       +- InMemoryRelation [id#35L, category#37, category_name#40, priority#44], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- *(1) Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37, concat(Category , cast(id#35L as string)) AS category_name#40, cast((rand(-1294804350127073887) * 10.0) as int) AS priority#44]
#                +- *(1) Range (0, 5000, step=1, splits=16)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
#    +- BroadcastHashJoin [category#27], [category#37], Inner, BuildRight, false
#       :- Filter isnotnull(category#27)
#       :  +- InMemoryTableScan [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], [isnotnull(category#27)]
#       :        +- InMemoryRelation [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], StorageLevel(disk, memory, deserialized, 1 replicas)
#       :              +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % 50) as string)) AS category#27]
#       :                 +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * 500000.0) as bigint) AS upload_bytes#20L]
#       :                    +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * 1000000.0) as bigint) AS download_bytes#14L]
#       :                       +- *(1) Project [id#0L, cast((id#0L % 500000) as string) AS account_number#2, date_add(2025-01-01, cast((id#0L % 90) as int)) AS event_date#5, cast((rand(-1990789066734320550) * 3600.0) as int) AS session_duration#9]
#       :                          +- *(1) Range (0, 2000000, step=1, splits=200)
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=601]
#          +- InMemoryTableScan [category#37, category_name#40, priority#44]
#                +- InMemoryRelation [id#35L, category#37, category_name#40, priority#44], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37, concat(Category , cast(id#35L as string)) AS category_name#40, cast((rand(-1294804350127073887) * 10.0) as int) AS priority#44]
#                         +- *(1) Range (0, 5000, step=1, splits=16)
#
#
# --- GOOD PLAN ---
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [category])
# :- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % cast(50 as bigint)) as string)) AS category#27]
# :  +- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * cast(500000 as double)) as bigint) AS upload_bytes#20L]
# :     +- Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * cast(1000000 as double)) as bigint) AS download_bytes#14L]
# :        +- Project [id#0L, account_number#2, event_date#5, cast((rand(-1990789066734320550) * cast(3600 as double)) as int) AS session_duration#9]
# :           +- Project [id#0L, account_number#2, date_add(cast(2025-01-01 as date), cast((id#0L % cast(90 as bigint)) as int)) AS event_date#5]
# :              +- Project [id#0L, cast((id#0L % cast(500000 as bigint)) as string) AS account_number#2]
# :                 +- Range (0, 2000000, step=1, splits=Some(200))
# +- ResolvedHint (strategy=broadcast)
#    +- Project [category#37, category_name#40, priority#44]
#       +- Project [id#35L, category#37, category_name#40, cast((rand(-1294804350127073887) * cast(10 as double)) as int) AS priority#44]
#          +- Project [id#35L, category#37, concat(Category , cast(id#35L as string)) AS category_name#40]
#             +- Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37]
#                +- Range (0, 5000, step=1, splits=Some(16))
#
# == Analyzed Logical Plan ==
# category: string, id: bigint, account_number: string, event_date: date, session_duration: int, download_bytes: bigint, upload_bytes: bigint, category_name: string, priority: int
# Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
# +- Join Inner, (category#27 = category#37)
#    :- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % cast(50 as bigint)) as string)) AS category#27]
#    :  +- Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * cast(500000 as double)) as bigint) AS upload_bytes#20L]
#    :     +- Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * cast(1000000 as double)) as bigint) AS download_bytes#14L]
#    :        +- Project [id#0L, account_number#2, event_date#5, cast((rand(-1990789066734320550) * cast(3600 as double)) as int) AS session_duration#9]
#    :           +- Project [id#0L, account_number#2, date_add(cast(2025-01-01 as date), cast((id#0L % cast(90 as bigint)) as int)) AS event_date#5]
#    :              +- Project [id#0L, cast((id#0L % cast(500000 as bigint)) as string) AS account_number#2]
#    :                 +- Range (0, 2000000, step=1, splits=Some(200))
#    +- ResolvedHint (strategy=broadcast)
#       +- Project [category#37, category_name#40, priority#44]
#          +- Project [id#35L, category#37, category_name#40, cast((rand(-1294804350127073887) * cast(10 as double)) as int) AS priority#44]
#             +- Project [id#35L, category#37, concat(Category , cast(id#35L as string)) AS category_name#40]
#                +- Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37]
#                   +- Range (0, 5000, step=1, splits=Some(16))
#
# == Optimized Logical Plan ==
# Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
# +- Join Inner, (category#27 = category#37), rightHint=(strategy=broadcast)
#    :- Filter isnotnull(category#27)
#    :  +- InMemoryRelation [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % 50) as string)) AS category#27]
#    :           +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * 500000.0) as bigint) AS upload_bytes#20L]
#    :              +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * 1000000.0) as bigint) AS download_bytes#14L]
#    :                 +- *(1) Project [id#0L, cast((id#0L % 500000) as string) AS account_number#2, date_add(2025-01-01, cast((id#0L % 90) as int)) AS event_date#5, cast((rand(-1990789066734320550) * 3600.0) as int) AS session_duration#9]
#    :                    +- *(1) Range (0, 2000000, step=1, splits=200)
#    +- Project [category#37, category_name#40, priority#44]
#       +- InMemoryRelation [id#35L, category#37, category_name#40, priority#44], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- *(1) Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37, concat(Category , cast(id#35L as string)) AS category_name#40, cast((rand(-1294804350127073887) * 10.0) as int) AS priority#44]
#                +- *(1) Range (0, 5000, step=1, splits=16)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [category#27, id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category_name#40, priority#44]
#    +- BroadcastHashJoin [category#27], [category#37], Inner, BuildRight, false
#       :- Filter isnotnull(category#27)
#       :  +- InMemoryTableScan [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], [isnotnull(category#27)]
#       :        +- InMemoryRelation [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, category#27], StorageLevel(disk, memory, deserialized, 1 replicas)
#       :              +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, upload_bytes#20L, concat(cat_, cast((id#0L % 50) as string)) AS category#27]
#       :                 +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, download_bytes#14L, cast((rand(518242696327550130) * 500000.0) as bigint) AS upload_bytes#20L]
#       :                    +- *(1) Project [id#0L, account_number#2, event_date#5, session_duration#9, cast((rand(2097948357877405321) * 1000000.0) as bigint) AS download_bytes#14L]
#       :                       +- *(1) Project [id#0L, cast((id#0L % 500000) as string) AS account_number#2, date_add(2025-01-01, cast((id#0L % 90) as int)) AS event_date#5, cast((rand(-1990789066734320550) * 3600.0) as int) AS session_duration#9]
#       :                          +- *(1) Range (0, 2000000, step=1, splits=200)
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=640]
#          +- InMemoryTableScan [category#37, category_name#40, priority#44]
#                +- InMemoryRelation [id#35L, category#37, category_name#40, priority#44], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [id#35L, concat(cat_, cast(id#35L as string)) AS category#37, concat(Category , cast(id#35L as string)) AS category_name#40, cast((rand(-1294804350127073887) * 10.0) as int) AS priority#44]
#                         +- *(1) Range (0, 5000, step=1, splits=16)
